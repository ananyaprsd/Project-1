# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("/content/salary_data.csv")
df
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
df.isnull().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
df.shape
# Out:
# (30, 2)

# %%
df.columns
# Out:
# Index(['YearsExperience', 'Salary'], dtype='object')

# %%
df.dtypes
# Out:
# YearsExperience    float64
# Salary             float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 612.0 bytes

# %%
df
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
df.describe()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000

# %%
import matplotlib.pyplot as plt
plt.scatter(df.YearsExperience,df.Salary,color="red",marker="*")
plt.title("YearsExperience vs Salary")
plt.xlabel("YearsExperience")
plt.ylabel("Salary")
plt.show()

# %%
x=df.iloc[:,:-1]
print(type(x))
print(x)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#     YearsExperience
# 0               1.1
# 1               1.3
# 2               1.5
# 3               2.0
# 4               2.2
# 5               2.9
# 6               3.0
# 7               3.2
# 8               3.2
# 9               3.7
# 10              3.9
# 11              4.0
# 12              4.0
# 13              4.1
# 14              4.5
# 15              4.9
# 16              5.1
# 17              5.3
# 18              5.9
# 19              6.0
# 20              6.8
# 21              7.1
# 22              7.9
# 23              8.2
# 24              8.7
# 25              9.0
# 26              9.5
# 27              9.6
# 28             10.3
# 29             10.5

# %%
y=df.iloc[:,1]
print(type(y))
print(y)
# Out:
# <class 'pandas.core.series.Series'>
# 0      39343.0
# 1      46205.0
# 2      37731.0
# 3      43525.0
# 4      39891.0
# 5      56642.0
# 6      60150.0
# 7      54445.0
# 8      64445.0
# 9      57189.0
# 10     63218.0
# 11     55794.0
# 12     56957.0
# 13     57081.0
# 14     61111.0
# 15     67938.0
# 16     66029.0
# 17     83088.0
# 18     81363.0
# 19     93940.0
# 20     91738.0
# 21     98273.0
# 22    101302.0
# 23    113812.0
# 24    109431.0
# 25    105582.0
# 26    116969.0
# 27    112635.0
# 28    122391.0
# 29    121872.0
# Name: Salary, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (24, 1)
# (6, 1)
# (24,)
# (6,)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_predict=model.predict(x_test)
y_predict
# Out:
# array([ 92597.22498821,  68679.6932947 , 114674.94655144, 122034.18707252,
#         47521.87679659, 107315.70603036])

# %%
new_df=pd.DataFrame({"Actual":y_test,"Predict":y_predict})
new_df
# Out:
#       Actual        Predict
# 21   98273.0   92597.224988
# 14   61111.0   68679.693295
# 26  116969.0  114674.946551
# 28  122391.0  122034.187073
# 4    39891.0   47521.876797
# 24  109431.0  107315.706030

# %%
model.score(x_train,y_train)*100
# Out:
# 94.50002223975211

# %%
model.score(x_test,y_test)*100
# Out:
# 97.16411824921472

# %% [markdown]
# Mean square error

# %%
from sklearn.metrics import mean_squared_error
mse=mean_squared_error(y_test,y_predict)
print("Mean Squared Error:",mse)
# Out:
# Mean Squared Error: 26265714.354416553

# %%
rmse=np.sqrt(mean_squared_error(y_test,y_predict))
print("Root Mean Squared Error:",rmse)
# Out:
# Root Mean Squared Error: 5125.00871749664

# %%
from sklearn.metrics import mean_absolute_error
mae=mean_absolute_error(y_test,y_predict)
print("MeanAbsolute Error:",mae)
# Out:
# MeanAbsolute Error: 4273.584241458634

# %%
from sklearn.metrics import r2_score
r2=r2_score(y_test,y_predict)*100
print("R2 Score:",r2)
# Out:
# R2 Score: 97.16411824921472

# %%
plt.scatter(x_train,y_train,color="red",marker="*")
plt.plot(x_train,model.predict(x_train),color="blue")
plt.title("Linear Regression(training set)")
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %%
plt.scatter(x_test,y_test,color="red",marker="*")
plt.plot(x_train,model.predict(x_train),color="blue")
plt.title("Linear Regression(testing set)")
plt.xlabel("x")
plt.ylabel("y")
plt.show()
